# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
resignation = pd.read_csv('congressional_resignations.csv')
genericBallot = pd.read_csv('generic_topline_historical.csv')

# %%
resignation.head()
# Out:
#          Member Party District Congress Resignation Date  \
# 0    Pat Tiberi     R    OH-12    115th        1/15/2018
# 1    Al Franken     D   MN-SEN    115th         1/2/2018
# 2  Trent Franks     R    AZ-08    115th        12/8/2017
# 3  John Conyers     D    MI-13    115th        12/5/2017
# 4    Tim Murphy     R    PA-18    115th       10/21/2017
#
#                                          Reason                    Source  \
# 0  Took a job with the Ohio Business Roundtable            New York Times
# 1    Sexual harassment/groping/unwanted kissing  Minneapolis Star Tribune
# 2          Sexual harassment/surrogacy pressure                       CNN
# 3      Sexual harassment/inappropriate touching           Washington Post
# 4        Extramarital affair/abortion hypocrisy                  POLITICO
#
#   Category
# 0        D
# 1        X
# 2        X
# 3        X
# 4        A

# %%
resignTest = resignation[resignation['Category'].str.contains('X|A|B|C|D|E|F|G|H|I')==True]

# %%
resignTest.Category.unique()
# Out:
# array(['D', 'X', 'A', 'C', 'B', 'F', 'D & F', 'B & D', 'B & E', 'D & E',
#        'E', 'E & F', 'B & C', 'G', 'E & G', 'B & G', 'F & G', 'D & G',
#        'H', 'I', 'C & F'], dtype=object)

# %%
resignTest
# Out:
#               Member Party District Congress Resignation Date  \
# 0         Pat Tiberi     R    OH-12    115th        1/15/2018
# 1         Al Franken     D   MN-SEN    115th         1/2/2018
# 2       Trent Franks     R    AZ-08    115th        12/8/2017
# 3       John Conyers     D    MI-13    115th        12/5/2017
# 4         Tim Murphy     R    PA-18    115th       10/21/2017
# ..               ...   ...      ...      ...              ...
# 610       George Ray     R    NY-26     57th        9/11/1902
# 611     James Butler     D    MO-12     57th        6/28/1902
# 612    William Moody     R    MA-06     57th         5/1/1902
# 613        John Rhea     D    KY-03     57th        3/25/1902
# 614  Nicholas Muller     D    NY-07     57th       11/22/1901
#
#                                                 Reason  \
# 0         Took a job with the Ohio Business Roundtable
# 1           Sexual harassment/groping/unwanted kissing
# ...

# %%
resignTest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 615 entries, 0 to 614
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Member            615 non-null    object
#  1   Party             615 non-null    object
#  2   District          615 non-null    object
#  3   Congress          615 non-null    object
#  4   Resignation Date  615 non-null    object
#  5   Reason            615 non-null    object
#  6   Source            615 non-null    object
#  7   Category          615 non-null    object
# dtypes: object(8)
# memory usage: 43.2+ KB

# %%
resignTest.Source.unique()
# Out:
# array(['New York Times', 'Minneapolis Star Tribune', 'CNN',
#        'Washington Post', 'POLITICO', 'Bozeman Daily Chronicle',
#        'Associated Press', 'GeorgiaPol', 'Washington Examiner',
#        'Los Angeles Times', 'NBC News', 'Detroit News',
#        'Kentucky Center for Investigative Reporting', 'The Oklahoman',
#        'USA Today', 'Philadelphia Inquirer', 'The Missoulian',
#        'Camel City Dispatch', 'Roll Call', 'Boston Globe',
#        'U.S. House of Representatives', 'The Oregonian', 'Las Vegas Sun',
#        'Wilson Center', 'ABC News', 'CREW', 'The Week', 'NPR', 'Lexology',
#        'KNTV', 'New York Daily News', 'Denver Post',
#        'New Orleans Times-Picayune', 'Reuters', 'The Guardian',
#        'FOX News', 'U.S. Congress', 'San Diego Union-Tribune',
#        'Securities & Exchange Commission', 'CQ Almanac',
#        'Minnesota Public Radio', 'Fletcher/Pence Inaugural',
#        'Plainview Daily Herald', 'Northwest Florida Daily News',
# ...

# %%
sns.catplot(x="Party", hue="Category", 
                data=resignTest, kind="count")
