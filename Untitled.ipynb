# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import pearsonr
from scipy import stats

# %%
usa = pd.read_csv('DST.csv')

# %%
whr.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
whr[whr['Country name']=='United States']
# Out:
#        Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1836  United States  2006        7.182              10.924           0.965
# 1837  United States  2007        7.513              10.933             NaN
# 1838  United States  2008        7.280              10.922           0.953
# 1839  United States  2009        7.158              10.888           0.912
# 1840  United States  2010        7.164              10.905           0.926
# 1841  United States  2011        7.115              10.913           0.922
# 1842  United States  2012        7.026              10.928           0.903
# 1843  United States  2013        7.249              10.939           0.925
# 1844  United States  2014        7.151              10.956           0.902
# 1845  United States  2015        6.864              10.977           0.904
# 1846  United States  2016        6.804              10.986           0.897
# ...

# %%
germany
# Out:
#     year  nkill  terrtotal  suicides    ddfat
# 0   1970     35        197       NaN      NaN
# 1   1971     24         83       NaN      NaN
# 2   1972     10         45       NaN      NaN
# 3   1973     45         78       NaN      NaN
# 4   1974     24         86       NaN      NaN
# 5   1975     31        201       NaN      NaN
# 6   1976     11         63       NaN      NaN
# 7   1977     11         35       NaN      NaN
# 8   1978     16         32       NaN      NaN
# 9   1979     19         78       NaN      NaN
# 10  1980     20         48       NaN      NaN
# 11  1981     13         34   27596.0      NaN
# 12  1982     17         62   28242.0  26173.0
# 13  1983     10         20   28295.0  24635.0
# 14  1984      3        785   29286.0  24762.0
# 15  1985      3         16   29453.0  23167.0
# 16  1986      3         41   30904.0  25017.0
# 17  1987      1          2   30796.0  24094.0
# 18  1988      1          2   30407.0  23833.0
# ...

# %%
germany.drop('Unnamed: 0',axis=1,inplace=True)

# %%
sns.lineplot(x="year", y="ddfat", data=germany)
# Out:
# <AxesSubplot: xlabel='year', ylabel='ddfat'>

# %%
sns.lineplot(x="year", y="terrtotal", data=germany)
# Out:
# <AxesSubplot: xlabel='year', ylabel='terrtotal'>

# %%
sns.lineplot(x="year", y="nkill", data=germany)
# Out:
# <AxesSubplot: xlabel='year', ylabel='nkill'>

# %%
sns.lineplot(x="year", y="Freedom to make life choices", data=whr[whr['Country name']=='United States'])

# %%
sns.lineplot(x="year", y="Freedom to make life choices", data=whr[whr['Country name']=='United States'])

# %%
sns.lineplot(x="year", y="Freedom to make life choices", data=whr[whr['Country name']=='United States'])

# %%
sns.lineplot(x="year", y="Freedom to make life choices", data=whr[whr['Country name']=='United States'])

# %%
germany.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   year       49 non-null     int64
#  1   nkill      49 non-null     int64
#  2   terrtotal  49 non-null     int64
#  3   suicides   38 non-null     float64
#  4   ddfat      37 non-null     float64
# dtypes: float64(2), int64(3)
# memory usage: 2.0 KB

# %%
germany.isna().sum()
# Out:
# year          0
# nkill         0
# terrtotal     0
# suicides     11
# ddfat        12
# dtype: int64

# %%
germany.loc[germany['ddfat'].isna() == False]
# Out:
#     year  nkill  terrtotal  suicides    ddfat
# 12  1982     17         62   28242.0  26173.0
# 13  1983     10         20   28295.0  24635.0
# 14  1984      3        785   29286.0  24762.0
# 15  1985      3         16   29453.0  23167.0
# 16  1986      3         41   30904.0  25017.0
# 17  1987      1          2   30796.0  24094.0
# 18  1988      1          2   30407.0  23833.0
# 19  1989      5         21   30232.0  22424.0
# 20  1990      5         12   30906.0  22587.0
# 21  1991      7         16   30810.0  20159.0
# 22  1992      2          5   30484.0  18290.0
# 23  1993     10       1016   31102.0  17908.0
# 24  1994     11         28   31142.0  17308.0
# 25  1995    178        916   31284.0  17732.0
# 26  1996      2         86   30903.0  17749.0
# 27  1997      2         21   30535.0  16711.0
# 28  1998      4          7   30575.0  16673.0
# 29  1999     20         60   29199.0  16572.0
# 30  2000      8         18   29350.0  17380.0
# ...
